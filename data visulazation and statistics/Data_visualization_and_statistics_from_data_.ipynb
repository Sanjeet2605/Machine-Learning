# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
print("Question 1.")
print()
print()
print("mean of pregs attribute : ", data["pregs"].mean())
print("mean of plas attribute : ", data["plas"].mean())
print("mean of pres attribute : ", data["pres"].mean())
print("mean of skin attribute : ", data["skin"].mean())
print("mean of BMI attribute : ", data["BMI"].mean())
print("mean of test attribute : ", data["test"].mean())
print("mean of pedi attribute : ", data["pedi"].mean())
print("mean of Age attribute : ", data["Age"].mean())
print()
print()
print("median of pregs attribute : ", data["pregs"].median())
print("median of plas attribute : ", data["plas"].median())
print("median of pres attribute : ", data["pres"].median())
print("median of skin attribute : ", data["skin"].median())
print("median of BMI attribute : ", data["BMI"].median())
print("median of test attribute : ", data["test"].median())
print("median of pedi attribute : ", data["pedi"].median())
print("median of Age attribute : ", data["Age"].median())
print()
print()
print("mode of pregs attribute : ", data["pregs"].mode())
print("mode of plas attribute : ", data["plas"].mode())
print("mode of pres attribute : ", data["pres"].mode())
print("mode of skin attribute : ", data["skin"].mode())
print("mode of BMI attribute : ", data["BMI"].mode())
print("mode of test attribute : ", data["test"].mode())
print("mode of pedi attribute : ", data["pedi"].mode())
print("mode of Age attribute : ", data["Age"].mode())
print()
print()
print("min of pregs attribute : ", data["pregs"].min())
print("min of plas attribute : ", data["plas"].min())
print("min of pres attribute : ", data["pres"].min())
print("min of skin attribute : ", data["skin"].min())
print("min of BMI attribute : ", data["BMI"].min())
print("min of test attribute : ", data["test"].min())
print("min of pedi attribute : ", data["pedi"].min())
print("min of Age attribute : ", data["Age"].min())
print()
print()
print("max of pregs attribute : ", data["pregs"].max())
print("max of plas attribute : ", data["plas"].max())
print("max of pres attribute : ", data["pres"].max())
print("max of skin attribute : ", data["skin"].max())
print("max of BMI attribute : ", data["BMI"].max())
print("max of test attribute : ", data["test"].max())
print("max of pedi attribute : ", data["pedi"].max())
print("max of Age attribute : ", data["Age"].max())
print()
print()
print("standard deviation of pregs attribute : ", data["pregs"].std())
print("standard deviation of plas attribute : ", data["plas"].std())
print("standard deviation of pres attribute : ", data["pres"].std())
print("standard deviation of skin attribute : ", data["skin"].std())
print("standard deviation of BMI attribute : ", data["BMI"].std())
print("standard deviation of test attribute : ", data["test"].std())
print("standard deviation of pedi attribute : ", data["pedi"].std())
print("standard deviation of Age attribute : ", data["Age"].std())
# Out:
# Question 1.
#
#
# mean of pregs attribute :  3.8450520833333335
# mean of plas attribute :  120.89453125
# mean of pres attribute :  69.10546875
# mean of skin attribute :  20.536458333333332
# mean of BMI attribute :  31.992578124999998
# mean of test attribute :  79.79947916666667
# mean of pedi attribute :  0.47187630208333325
# mean of Age attribute :  33.240885416666664
#
#
# median of pregs attribute :  3.0
# median of plas attribute :  117.0
# median of pres attribute :  72.0
# median of skin attribute :  23.0
# median of BMI attribute :  32.0
# median of test attribute :  30.5
# median of pedi attribute :  0.3725
# median of Age attribute :  29.0
#
#
# mode of pregs attribute :  0    1
# Name: pregs, dtype: int64
# mode of plas attribute :  0     99
# 1    100
# Name: plas, dtype: int64
# mode of pres attribute :  0    70
# Name: pres, dtype: int64
# mode of skin attribute :  0    0
# Name: skin, dtype: int64
# mode of BMI attribute :  0    32.0
# Name: BMI, dtype: float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
print("Question 2.")
print()
print()
figure, axis = plt.subplots(2, 4)
# between age and pregs
axis[0, 0].scatter(data["Age"], data["pregs"])
axis[0, 0].set_title("b/w Age and pregs")

# between age and plas
axis[0, 1].scatter(data["Age"], data["plas"])
axis[0, 1].set_title("b/w Age and plas")

# between age and pres
axis[0, 2].scatter(data["Age"], data["pres"])
axis[0, 2].set_title("b/w Age and pres")

# between age and skin
axis[0, 3].scatter(data["Age"], data["skin"])
axis[0, 3].set_title("b/w Age and skin")

# between age and BMI
axis[1, 0].scatter(data["Age"], data["BMI"])
axis[1, 0].set_title("b/w Age and BMI")

# between age and test
axis[1, 1].scatter(data["Age"], data["test"])
axis[1, 1].set_title("b/w Age and test")

# between age and pedi
axis[1, 2].scatter(data["Age"], data["pedi"])
axis[1, 2].set_title("b/w Age and pedi")

# Combine all the operations and display
plt.show()

figure, axis = plt.subplots(2, 4)
# between BMI and pregs
axis[0, 0].scatter(data["BMI"], data["pregs"])
axis[0, 0].set_title("b/w BMI and pregs")

# between BMI and plas
axis[0, 1].scatter(data["BMI"], data["plas"])
axis[0, 1].set_title("b/w BMI and plas")

# between BMI and pres
axis[0, 2].scatter(data["BMI"], data["pres"])
axis[0, 2].set_title("b/w Age and pres")

# between BMI and skin
axis[0, 3].scatter(data["BMI"], data["skin"])
axis[0, 3].set_title("b/w Age and skin")

# between BMI and Age
axis[1, 0].scatter(data["BMI"], data["Age"])
axis[1, 0].set_title("b/w Age and BMI")

# between BMI and test
axis[1, 1].scatter(data["BMI"], data["test"])
axis[1, 1].set_title("b/w Age and test")

# between BMI and pedi
axis[1, 2].scatter(data["BMI"], data["pedi"])
axis[1, 2].set_title("b/w Age and pedi")

# Combine all the operations and display
plt.show()
# Out:
# Question 2.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
print("Question 3.")
print()
print()
# for correlation using corr value
print("correlation coeff between Age and pregs attribute : ",
      data["pregs"].corr(data["Age"]))
print("correlation coeff between Age and plas attribute : ",
      data["plas"].corr(data["Age"]))
print("correlation coeff between Age and pres attribute : ",
      data["pres"].corr(data["Age"]))
print("correlation coeff between Age and skin attribute : ",
      data["skin"].corr(data["Age"]))
print("correlation coeff between Age and BMI attribute : ",
      data["BMI"].corr(data["Age"]))
print("correlation coeff between Age and test attribute : ",
      data["test"].corr(data["Age"]))
print("correlation coeff between Age and pedi attribute : ",
      data["pedi"].corr(data["Age"]))
print("correlation coeff between Age and Age attribute : ",
      data["Age"].corr(data["Age"]))
print()
print()
print("correlation coeff between BMI and pregs attribute : ",
      data["pregs"].corr(data["BMI"]))
print("correlation coeff between BMI and plas attribute : ",
      data["plas"].corr(data["BMI"]))
print("correlation coeff between BMI and pres attribute : ",
      data["pres"].corr(data["BMI"]))
print("correlation coeff between BMI and skin attribute : ",
      data["skin"].corr(data["BMI"]))
print("correlation coeff between BMI and BMI attribute : ",
      data["BMI"].corr(data["BMI"]))
print("correlation coeff between BMI and test attribute : ",
      data["test"].corr(data["BMI"]))
print("correlation coeff between BMI and pedi attribute : ",
      data["pedi"].corr(data["BMI"]))
print("correlation coeff between BMI and Age attribute : ",
      data["Age"].corr(data["BMI"]))
# Out:
# Question 3.
#
#
# correlation coeff between Age and pregs attribute :  0.5443412284023394
# correlation coeff between Age and plas attribute :  0.2635143198243338
# correlation coeff between Age and pres attribute :  0.23952794642136363
# correlation coeff between Age and skin attribute :  -0.11397026236774165
# correlation coeff between Age and BMI attribute :  0.03624187009229417
# correlation coeff between Age and test attribute :  -0.04216295473537674
# correlation coeff between Age and pedi attribute :  0.033561312434805514
# correlation coeff between Age and Age attribute :  1.0
#
#
# correlation coeff between BMI and pregs attribute :  0.017683090727830596
# correlation coeff between BMI and plas attribute :  0.22107106945898294
# correlation coeff between BMI and pres attribute :  0.2818052888499106
# correlation coeff between BMI and skin attribute :  0.39257320415903835
# correlation coeff between BMI and BMI attribute :  1.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
print("Question 3.")
print()
print()
# plotting histogram for preg and skin respectively
data.hist(column="pregs", color="skyblue", edgecolor="black")
plt.xlabel("no of times pregnant")
plt.ylabel("no of patiemts")
plt.show()
print()
print()
data.hist(column="skin", color="lightpink", edgecolor="black")
plt.xlabel("Triceps skin fold thickness")
plt.ylabel("no of patiemts")
plt.show()
# Out:
# Question 3.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
# divide class wrt two respective velues and plot the histogram for them respectively
data.groupby("class").hist(column="pregs", edgecolor="black")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("pima-indians-diabetes.csv")
# boxplot for pregs
plt.boxplot(data["pregs"])
plt.show()
# boxplot for plas
plt.boxplot(data["plas"])
plt.show()
# boxplot for pres
plt.boxplot(data["pres"])
plt.show()
# boxplot for skin
plt.boxplot(data["skin"])
plt.show()
# boxplot for BMI
plt.boxplot(data["BMI"])
plt.show()
# boxplot for test
plt.boxplot(data["test"])
plt.show()
# boxplot for pedi
plt.boxplot(data["pedi"])
plt.show()
# boxplot for predi Age
plt.boxplot(data["Age"])
plt.show()
